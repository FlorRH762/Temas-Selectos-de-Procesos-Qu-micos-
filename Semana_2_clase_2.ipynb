# %%
a= 3
b= 4.5
c= 'alumna'
d= False

# %%
lista1=[10,20,30,40]
lista2=['uno','dos','tres']
lista3= ['uno',2,3.15,[10,20,30]]

# %%
lista1[2]
# Out:
# 30

# %%
lista2[1]
# Out:
# 'dos'

# %%
lista1[2]=25

# %% [markdown]
# Para llamar los datos

# %%
lista3[3]
# Out:
# [10, 20, 30]

# %%
lista1
# Out:
# [10, 20, 25, 40]

# %%
lista1.append(12)

# %%
lista1.remove(12)

# %% [markdown]
# Cadenas de texto
# Las cadenas de texto de Payton son inmutables;no se pueden modificar

# %%
a= 'esto es una cadena '
a
# Out:
# 'esto es una cadena '

# %%
a[8]
# Out:
# 'u'

# %%
b= a.replace('cadena','cadena grande')

# %%
b
# Out:
# 'esto es una cadena grande '

# %% [markdown]
# Muchos objetos de Python se pueden transformar en una cadena de texto utilizando la función str()

# %%
g=7.8
g
# Out:
# 7.8

# %% [markdown]
# Para convertir de número a texto

# %%
h=str(g)
h
# Out:
# '7.8'

# %% [markdown]
# Sumar dos cadenas las

# %%
a= 'primera mitad'
b= 'y segunda mitad'

# %%
a+b
# Out:
# 'primera mitady segunda mitad'

# %% [markdown]
# Operadores binarios

# %% [markdown]
# Datos Boolenaos

# %%
a=7
b=10

a > b
# Out:
# False

# %%
a=5
b=10
a < b
# Out:
# True
